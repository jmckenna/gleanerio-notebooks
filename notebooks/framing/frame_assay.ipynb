# %% [markdown]
# # GleanerIO JSON-LD Framing Processor
#
# ## About
#
# - convert this from doing SHACL to doing framing

# %% [markdown]
# ### Imports

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import dask
import boto3
import pandas as pd
import json, io
import getpass
import pathlib
import s3fs
import kglab
from rdflib import Graph  #, plugin
from pyld import jsonld

# %% [markdown]
# ### Set up Dask client

# %%
from dask.distributed import Client    #, progress
client = Client(threads_per_worker=5, n_workers=4)
client
# Out:
# <Client: 'tcp://127.0.0.1:37081' processes=4 threads=20, memory=31.18 GiB>

# %% [markdown]
# ### File Access

# %%
## Set up the S3 File system
# oss = s3fs.S3FileSystem(
#     anon=True,
#     client_kwargs = {"endpoint_url":"https://oss.geocodes-dev.earthcube.org"}
# )

## Access controlled s3
session = boto3.Session(profile_name='default' ,   region_name="us-east-1")
s3 = session.client('s3')  # needed later for listing objects
s3r = session.resource('s3')
oss = s3fs.S3FileSystem( profile="default")


## Manual code access
# ACCESS_CODE = getpass.getpass()
# SECRET_CODE = getpass.getpass()

# oss = s3fs.S3FileSystem(
#     anon=False,
#     key=ACCESS_CODE,
#     secret=SECRET_CODE,
#     client_kwargs = {"endpoint_url":"https://oss.geocodes-dev.earthcube.org"}
# )

# %% [markdown]
# ## Dask processing

# %% [markdown]
# ### Define Delayed Definitions

# %%
# Simple JSON-LD framing inside Dask function
@dask.delayed()
def citation_frame(fn):
    # or preferably open in text mode and json.load from the file
    frame = {"@context":{"@vocab": "https://schema.org/"}, "@type": "Organization", "@explicit": "true", "description": {}};
    #   citationframe = {"@context":{"@vocab": ctx}, "@type": "Dataset", "@explicit": "true", "citation": {}};
    with oss.open(fn, 'rb') as f:
        #return json.loads(f.read().replace('\n',' '))
        try:
            jld = json.loads(f.read().decode("utf-8", "ignore").replace('\n',' '))
            framed = jsonld.frame(jld, frame)
            return framed   # ['citation']
        except:
            return ""

# %%
# %%time
# process the files

fns = oss.ls('gleaner.oih/summoned/edmo')
o = [citation_frame(f) for f in fns]

results = dask.compute(*o)  ## Wait..  can I just dask.compute(o)  ????
print(len(results))
# Out:
# 4527
# CPU times: user 4.47 s, sys: 360 ms, total: 4.83 s
# Wall time: 35.2 s

# %% [markdown]
# ### Loop on results and load to graph

# %%
### Single print
print(json.dumps(results[10]))
### Loop on results and load to graph
# You likely don't want to do this..   prints a lot of data
# for r in range(len(results)):
#     print(r)
#     print(json.dumps(results[r]))
# Out:
# {"@context": {"@vocab": "https://schema.org/"}, "@id": "https://edmo.seadatanet.org/report/343", "@type": "Organization", "description": "The Department of Geology of the Faculty of Science of the Sea is carrying out sediment research in diverse coastal sedimentary environments. These studies have been performed by professors and postgraduate and postdoctoral researchers. The research covers the production of process-answer models for the studied environment."}

# %%
rnamespaces = {
    "schema":  "https://schema.org/",
    "shacl":   "http://www.w3.org/ns/shacl#" ,
}

rkg = kglab.KnowledgeGraph(
    name = "Schema.org shacl eval datagraph",
    base_uri = "https://example.org/id/",
    namespaces = rnamespaces,
)

g = rkg.rdf_graph()

for r in results:
    rkg.load_rdf_text(data=json.dumps(r), format="json-ld")

# %%
sparql = """
PREFIX schema: <https://schema.org/>
SELECT *
  WHERE {
    # ?s schema:description ?o .
  }
"""

df = rkg.query_as_df(sparql)

# %%
pdf = df.to_pandas()
# pdf.style.apply(change_color_group, axis=None)
pdf.info()
pdf.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3430 entries, 0 to 3429
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s       3430 non-null   object
#  1   o       3430 non-null   object
# dtypes: object(2)
# memory usage: 53.7+ KB
#                                            s  \
# 0  <https://edmo.seadatanet.org/report/3600>
# 1   <https://edmo.seadatanet.org/report/714>
# 2  <https://edmo.seadatanet.org/report/5102>
# 3  <https://edmo.seadatanet.org/report/3516>
# 4  <https://edmo.seadatanet.org/report/3963>
# 5    <https://edmo.seadatanet.org/report/75>
# 6  <https://edmo.seadatanet.org/report/2106>
# 7   <https://edmo.seadatanet.org/report/773>
# 8   <https://edmo.seadatanet.org/report/343>
# 9  <https://edmo.seadatanet.org/report/2402>
#
#                                                    o
# 0  Oceaneering is a global oilfield provider of e...
# 1  Estonian Marine Institute is one of many Tartu...
# 2  Oxford Archaeology (OA) has a 40-year history ...
# 3  Appalachian State University is located in Boo...
# 4  Woodside is Australia&rsquo;s largest independ...
# 5  For information relating to PowerGen Plc conta...
# 6  The Norwegian Coastal Administration (Kystverk...
# 7  Galway Campus is the largest of GMIT's five ca...
# 8  The Department of Geology of the Faculty of Sc...
# 9  The Max Planck Institute for Meteorology is an...

# %%
# Optional export to parquet and or CSV
df.to_parquet("./output/frameresults.parquet")

# %%
import marqo

mq = marqo.Client(url='http://ghost.lan:8882')


for index, row in pdf.iterrows():
    # print(row['s'], row['o'])
    mq.index("my-first-index").add_documents([{"Title": row['s'],"Description": row['o'] }])
# Out:
# 2022-12-29 21:56:48,650 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:48,955 logger:'marqo' INFO add_documents roundtrip: took 0.304s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.304s per doc.
# 2022-12-29 21:56:48,955 logger:'marqo' INFO add_documents Marqo index: took 0.289s for Marqo to process & index 1 docs (server unbatched), for an average of 0.289s per doc.
# 2022-12-29 21:56:48,955 logger:'marqo' INFO add_documents completed. total time taken: 0.305s.
# 2022-12-29 21:56:48,956 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,070 logger:'marqo' INFO add_documents roundtrip: took 0.114s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.114s per doc.
# 2022-12-29 21:56:49,071 logger:'marqo' INFO add_documents Marqo index: took 0.111s for Marqo to process & index 1 docs (server unbatched), for an average of 0.111s per doc.
# 2022-12-29 21:56:49,071 logger:'marqo' INFO add_documents completed. total time taken: 0.115s.
# 2022-12-29 21:56:49,072 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,173 logger:'marqo' INFO add_documents roundtrip: took 0.101s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.101s per doc.
# 2022-12-29 21:56:49,174 logger:'marqo' INFO add_documents Marqo index: took 0.098s for Marqo to process & index 1 docs (server unbatched), for an average of 0.098s per doc.
# 2022-12-29 21:56:49,174 logger:'marqo' INFO add_documents completed. total time taken: 0.103s.
# 2022-12-29 21:56:49,175 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,249 logger:'marqo' INFO add_documents roundtrip: took 0.074s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.074s per doc.
# 2022-12-29 21:56:49,249 logger:'marqo' INFO add_documents Marqo index: took 0.070s for Marqo to process & index 1 docs (server unbatched), for an average of 0.070s per doc.
# 2022-12-29 21:56:49,249 logger:'marqo' INFO add_documents completed. total time taken: 0.075s.
# 2022-12-29 21:56:49,250 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,319 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:49,320 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:49,320 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:49,321 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,401 logger:'marqo' INFO add_documents roundtrip: took 0.081s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.081s per doc.
# 2022-12-29 21:56:49,402 logger:'marqo' INFO add_documents Marqo index: took 0.078s for Marqo to process & index 1 docs (server unbatched), for an average of 0.078s per doc.
# 2022-12-29 21:56:49,402 logger:'marqo' INFO add_documents completed. total time taken: 0.082s.
# 2022-12-29 21:56:49,403 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,473 logger:'marqo' INFO add_documents roundtrip: took 0.070s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.070s per doc.
# 2022-12-29 21:56:49,473 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:49,473 logger:'marqo' INFO add_documents completed. total time taken: 0.071s.
# 2022-12-29 21:56:49,474 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,559 logger:'marqo' INFO add_documents roundtrip: took 0.085s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.085s per doc.
# 2022-12-29 21:56:49,559 logger:'marqo' INFO add_documents Marqo index: took 0.081s for Marqo to process & index 1 docs (server unbatched), for an average of 0.081s per doc.
# 2022-12-29 21:56:49,559 logger:'marqo' INFO add_documents completed. total time taken: 0.085s.
# 2022-12-29 21:56:49,560 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,631 logger:'marqo' INFO add_documents roundtrip: took 0.072s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.072s per doc.
# 2022-12-29 21:56:49,632 logger:'marqo' INFO add_documents Marqo index: took 0.068s for Marqo to process & index 1 docs (server unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:49,632 logger:'marqo' INFO add_documents completed. total time taken: 0.072s.
# 2022-12-29 21:56:49,633 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,730 logger:'marqo' INFO add_documents roundtrip: took 0.097s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.097s per doc.
# 2022-12-29 21:56:49,730 logger:'marqo' INFO add_documents Marqo index: took 0.094s for Marqo to process & index 1 docs (server unbatched), for an average of 0.094s per doc.
# 2022-12-29 21:56:49,731 logger:'marqo' INFO add_documents completed. total time taken: 0.098s.
# 2022-12-29 21:56:49,731 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,802 logger:'marqo' INFO add_documents roundtrip: took 0.071s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.071s per doc.
# 2022-12-29 21:56:49,803 logger:'marqo' INFO add_documents Marqo index: took 0.068s for Marqo to process & index 1 docs (server unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:49,803 logger:'marqo' INFO add_documents completed. total time taken: 0.072s.
# 2022-12-29 21:56:49,804 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,898 logger:'marqo' INFO add_documents roundtrip: took 0.094s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.094s per doc.
# 2022-12-29 21:56:49,898 logger:'marqo' INFO add_documents Marqo index: took 0.091s for Marqo to process & index 1 docs (server unbatched), for an average of 0.091s per doc.
# 2022-12-29 21:56:49,899 logger:'marqo' INFO add_documents completed. total time taken: 0.095s.
# 2022-12-29 21:56:49,899 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:49,968 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:49,968 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:49,969 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:49,969 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,073 logger:'marqo' INFO add_documents roundtrip: took 0.103s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.103s per doc.
# 2022-12-29 21:56:50,073 logger:'marqo' INFO add_documents Marqo index: took 0.100s for Marqo to process & index 1 docs (server unbatched), for an average of 0.100s per doc.
# 2022-12-29 21:56:50,074 logger:'marqo' INFO add_documents completed. total time taken: 0.104s.
# 2022-12-29 21:56:50,074 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,195 logger:'marqo' INFO add_documents roundtrip: took 0.121s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.121s per doc.
# 2022-12-29 21:56:50,195 logger:'marqo' INFO add_documents Marqo index: took 0.118s for Marqo to process & index 1 docs (server unbatched), for an average of 0.118s per doc.
# 2022-12-29 21:56:50,196 logger:'marqo' INFO add_documents completed. total time taken: 0.122s.
# 2022-12-29 21:56:50,196 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,287 logger:'marqo' INFO add_documents roundtrip: took 0.091s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.091s per doc.
# 2022-12-29 21:56:50,287 logger:'marqo' INFO add_documents Marqo index: took 0.087s for Marqo to process & index 1 docs (server unbatched), for an average of 0.087s per doc.
# 2022-12-29 21:56:50,288 logger:'marqo' INFO add_documents completed. total time taken: 0.091s.
# 2022-12-29 21:56:50,288 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,356 logger:'marqo' INFO add_documents roundtrip: took 0.068s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:50,357 logger:'marqo' INFO add_documents Marqo index: took 0.065s for Marqo to process & index 1 docs (server unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:50,357 logger:'marqo' INFO add_documents completed. total time taken: 0.069s.
# 2022-12-29 21:56:50,358 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,435 logger:'marqo' INFO add_documents roundtrip: took 0.077s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.077s per doc.
# 2022-12-29 21:56:50,435 logger:'marqo' INFO add_documents Marqo index: took 0.073s for Marqo to process & index 1 docs (server unbatched), for an average of 0.073s per doc.
# 2022-12-29 21:56:50,435 logger:'marqo' INFO add_documents completed. total time taken: 0.078s.
# 2022-12-29 21:56:50,436 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,502 logger:'marqo' INFO add_documents roundtrip: took 0.066s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:50,502 logger:'marqo' INFO add_documents Marqo index: took 0.062s for Marqo to process & index 1 docs (server unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:50,503 logger:'marqo' INFO add_documents completed. total time taken: 0.067s.
# 2022-12-29 21:56:50,503 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,572 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:50,573 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:50,573 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:50,574 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,646 logger:'marqo' INFO add_documents roundtrip: took 0.072s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.072s per doc.
# 2022-12-29 21:56:50,647 logger:'marqo' INFO add_documents Marqo index: took 0.068s for Marqo to process & index 1 docs (server unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:50,647 logger:'marqo' INFO add_documents completed. total time taken: 0.073s.
# 2022-12-29 21:56:50,647 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,714 logger:'marqo' INFO add_documents roundtrip: took 0.066s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:50,714 logger:'marqo' INFO add_documents Marqo index: took 0.063s for Marqo to process & index 1 docs (server unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:50,714 logger:'marqo' INFO add_documents completed. total time taken: 0.067s.
# 2022-12-29 21:56:50,715 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,784 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:50,785 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:50,785 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:50,785 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,854 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:50,855 logger:'marqo' INFO add_documents Marqo index: took 0.065s for Marqo to process & index 1 docs (server unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:50,855 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:50,856 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,925 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:50,925 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:50,926 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:50,926 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:50,989 logger:'marqo' INFO add_documents roundtrip: took 0.063s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:50,990 logger:'marqo' INFO add_documents Marqo index: took 0.059s for Marqo to process & index 1 docs (server unbatched), for an average of 0.059s per doc.
# 2022-12-29 21:56:50,990 logger:'marqo' INFO add_documents completed. total time taken: 0.064s.
# 2022-12-29 21:56:50,991 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,100 logger:'marqo' INFO add_documents roundtrip: took 0.109s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.109s per doc.
# 2022-12-29 21:56:51,100 logger:'marqo' INFO add_documents Marqo index: took 0.105s for Marqo to process & index 1 docs (server unbatched), for an average of 0.105s per doc.
# 2022-12-29 21:56:51,101 logger:'marqo' INFO add_documents completed. total time taken: 0.110s.
# 2022-12-29 21:56:51,101 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,168 logger:'marqo' INFO add_documents roundtrip: took 0.066s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:51,168 logger:'marqo' INFO add_documents Marqo index: took 0.063s for Marqo to process & index 1 docs (server unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:51,169 logger:'marqo' INFO add_documents completed. total time taken: 0.067s.
# 2022-12-29 21:56:51,169 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,258 logger:'marqo' INFO add_documents roundtrip: took 0.089s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.089s per doc.
# 2022-12-29 21:56:51,259 logger:'marqo' INFO add_documents Marqo index: took 0.085s for Marqo to process & index 1 docs (server unbatched), for an average of 0.085s per doc.
# 2022-12-29 21:56:51,259 logger:'marqo' INFO add_documents completed. total time taken: 0.090s.
# 2022-12-29 21:56:51,260 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,351 logger:'marqo' INFO add_documents roundtrip: took 0.091s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.091s per doc.
# 2022-12-29 21:56:51,352 logger:'marqo' INFO add_documents Marqo index: took 0.087s for Marqo to process & index 1 docs (server unbatched), for an average of 0.087s per doc.
# 2022-12-29 21:56:51,352 logger:'marqo' INFO add_documents completed. total time taken: 0.092s.
# 2022-12-29 21:56:51,353 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,417 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 21:56:51,418 logger:'marqo' INFO add_documents Marqo index: took 0.060s for Marqo to process & index 1 docs (server unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:51,418 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 21:56:51,419 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,492 logger:'marqo' INFO add_documents roundtrip: took 0.072s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.072s per doc.
# 2022-12-29 21:56:51,492 logger:'marqo' INFO add_documents Marqo index: took 0.068s for Marqo to process & index 1 docs (server unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:51,492 logger:'marqo' INFO add_documents completed. total time taken: 0.074s.
# 2022-12-29 21:56:51,493 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,562 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:51,562 logger:'marqo' INFO add_documents Marqo index: took 0.065s for Marqo to process & index 1 docs (server unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:51,563 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:51,563 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,625 logger:'marqo' INFO add_documents roundtrip: took 0.061s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.061s per doc.
# 2022-12-29 21:56:51,625 logger:'marqo' INFO add_documents Marqo index: took 0.058s for Marqo to process & index 1 docs (server unbatched), for an average of 0.058s per doc.
# 2022-12-29 21:56:51,625 logger:'marqo' INFO add_documents completed. total time taken: 0.062s.
# 2022-12-29 21:56:51,626 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,723 logger:'marqo' INFO add_documents roundtrip: took 0.097s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.097s per doc.
# 2022-12-29 21:56:51,723 logger:'marqo' INFO add_documents Marqo index: took 0.093s for Marqo to process & index 1 docs (server unbatched), for an average of 0.093s per doc.
# 2022-12-29 21:56:51,723 logger:'marqo' INFO add_documents completed. total time taken: 0.098s.
# 2022-12-29 21:56:51,724 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,792 logger:'marqo' INFO add_documents roundtrip: took 0.068s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:51,793 logger:'marqo' INFO add_documents Marqo index: took 0.064s for Marqo to process & index 1 docs (server unbatched), for an average of 0.064s per doc.
# 2022-12-29 21:56:51,793 logger:'marqo' INFO add_documents completed. total time taken: 0.069s.
# 2022-12-29 21:56:51,794 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,880 logger:'marqo' INFO add_documents roundtrip: took 0.085s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.085s per doc.
# 2022-12-29 21:56:51,881 logger:'marqo' INFO add_documents Marqo index: took 0.082s for Marqo to process & index 1 docs (server unbatched), for an average of 0.082s per doc.
# 2022-12-29 21:56:51,881 logger:'marqo' INFO add_documents completed. total time taken: 0.087s.
# 2022-12-29 21:56:51,882 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:51,942 logger:'marqo' INFO add_documents roundtrip: took 0.060s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:51,943 logger:'marqo' INFO add_documents Marqo index: took 0.057s for Marqo to process & index 1 docs (server unbatched), for an average of 0.057s per doc.
# 2022-12-29 21:56:51,943 logger:'marqo' INFO add_documents completed. total time taken: 0.061s.
# 2022-12-29 21:56:51,943 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,004 logger:'marqo' INFO add_documents roundtrip: took 0.060s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:52,004 logger:'marqo' INFO add_documents Marqo index: took 0.057s for Marqo to process & index 1 docs (server unbatched), for an average of 0.057s per doc.
# 2022-12-29 21:56:52,004 logger:'marqo' INFO add_documents completed. total time taken: 0.061s.
# 2022-12-29 21:56:52,005 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,070 logger:'marqo' INFO add_documents roundtrip: took 0.065s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:52,071 logger:'marqo' INFO add_documents Marqo index: took 0.062s for Marqo to process & index 1 docs (server unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:52,071 logger:'marqo' INFO add_documents completed. total time taken: 0.066s.
# 2022-12-29 21:56:52,071 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,174 logger:'marqo' INFO add_documents roundtrip: took 0.103s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.103s per doc.
# 2022-12-29 21:56:52,175 logger:'marqo' INFO add_documents Marqo index: took 0.099s for Marqo to process & index 1 docs (server unbatched), for an average of 0.099s per doc.
# 2022-12-29 21:56:52,175 logger:'marqo' INFO add_documents completed. total time taken: 0.104s.
# 2022-12-29 21:56:52,175 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,255 logger:'marqo' INFO add_documents roundtrip: took 0.079s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.079s per doc.
# 2022-12-29 21:56:52,255 logger:'marqo' INFO add_documents Marqo index: took 0.076s for Marqo to process & index 1 docs (server unbatched), for an average of 0.076s per doc.
# 2022-12-29 21:56:52,255 logger:'marqo' INFO add_documents completed. total time taken: 0.080s.
# 2022-12-29 21:56:52,256 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,323 logger:'marqo' INFO add_documents roundtrip: took 0.067s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.067s per doc.
# 2022-12-29 21:56:52,324 logger:'marqo' INFO add_documents Marqo index: took 0.063s for Marqo to process & index 1 docs (server unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:52,324 logger:'marqo' INFO add_documents completed. total time taken: 0.068s.
# 2022-12-29 21:56:52,325 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,389 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 21:56:52,389 logger:'marqo' INFO add_documents Marqo index: took 0.060s for Marqo to process & index 1 docs (server unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:52,390 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 21:56:52,390 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,455 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 21:56:52,455 logger:'marqo' INFO add_documents Marqo index: took 0.060s for Marqo to process & index 1 docs (server unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:52,455 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 21:56:52,456 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,546 logger:'marqo' INFO add_documents roundtrip: took 0.090s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.090s per doc.
# 2022-12-29 21:56:52,546 logger:'marqo' INFO add_documents Marqo index: took 0.086s for Marqo to process & index 1 docs (server unbatched), for an average of 0.086s per doc.
# 2022-12-29 21:56:52,547 logger:'marqo' INFO add_documents completed. total time taken: 0.091s.
# 2022-12-29 21:56:52,547 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,611 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 21:56:52,611 logger:'marqo' INFO add_documents Marqo index: took 0.060s for Marqo to process & index 1 docs (server unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:52,612 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 21:56:52,612 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,683 logger:'marqo' INFO add_documents roundtrip: took 0.070s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.070s per doc.
# 2022-12-29 21:56:52,683 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:52,683 logger:'marqo' INFO add_documents completed. total time taken: 0.071s.
# 2022-12-29 21:56:52,684 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,746 logger:'marqo' INFO add_documents roundtrip: took 0.062s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:52,747 logger:'marqo' INFO add_documents Marqo index: took 0.058s for Marqo to process & index 1 docs (server unbatched), for an average of 0.058s per doc.
# 2022-12-29 21:56:52,747 logger:'marqo' INFO add_documents completed. total time taken: 0.064s.
# 2022-12-29 21:56:52,748 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,813 logger:'marqo' INFO add_documents roundtrip: took 0.065s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:52,814 logger:'marqo' INFO add_documents Marqo index: took 0.061s for Marqo to process & index 1 docs (server unbatched), for an average of 0.061s per doc.
# 2022-12-29 21:56:52,814 logger:'marqo' INFO add_documents completed. total time taken: 0.066s.
# 2022-12-29 21:56:52,814 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,889 logger:'marqo' INFO add_documents roundtrip: took 0.074s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.074s per doc.
# 2022-12-29 21:56:52,889 logger:'marqo' INFO add_documents Marqo index: took 0.071s for Marqo to process & index 1 docs (server unbatched), for an average of 0.071s per doc.
# 2022-12-29 21:56:52,889 logger:'marqo' INFO add_documents completed. total time taken: 0.075s.
# 2022-12-29 21:56:52,890 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:52,952 logger:'marqo' INFO add_documents roundtrip: took 0.062s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:52,952 logger:'marqo' INFO add_documents Marqo index: took 0.059s for Marqo to process & index 1 docs (server unbatched), for an average of 0.059s per doc.
# 2022-12-29 21:56:52,952 logger:'marqo' INFO add_documents completed. total time taken: 0.063s.
# 2022-12-29 21:56:52,953 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,049 logger:'marqo' INFO add_documents roundtrip: took 0.096s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.096s per doc.
# 2022-12-29 21:56:53,050 logger:'marqo' INFO add_documents Marqo index: took 0.093s for Marqo to process & index 1 docs (server unbatched), for an average of 0.093s per doc.
# 2022-12-29 21:56:53,050 logger:'marqo' INFO add_documents completed. total time taken: 0.097s.
# 2022-12-29 21:56:53,051 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,149 logger:'marqo' INFO add_documents roundtrip: took 0.098s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.098s per doc.
# 2022-12-29 21:56:53,150 logger:'marqo' INFO add_documents Marqo index: took 0.095s for Marqo to process & index 1 docs (server unbatched), for an average of 0.095s per doc.
# 2022-12-29 21:56:53,150 logger:'marqo' INFO add_documents completed. total time taken: 0.099s.
# 2022-12-29 21:56:53,150 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,215 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 21:56:53,215 logger:'marqo' INFO add_documents Marqo index: took 0.061s for Marqo to process & index 1 docs (server unbatched), for an average of 0.061s per doc.
# 2022-12-29 21:56:53,216 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 21:56:53,216 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,285 logger:'marqo' INFO add_documents roundtrip: took 0.068s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:53,285 logger:'marqo' INFO add_documents Marqo index: took 0.065s for Marqo to process & index 1 docs (server unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:53,285 logger:'marqo' INFO add_documents completed. total time taken: 0.069s.
# 2022-12-29 21:56:53,286 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,379 logger:'marqo' INFO add_documents roundtrip: took 0.093s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.093s per doc.
# 2022-12-29 21:56:53,380 logger:'marqo' INFO add_documents Marqo index: took 0.090s for Marqo to process & index 1 docs (server unbatched), for an average of 0.090s per doc.
# 2022-12-29 21:56:53,380 logger:'marqo' INFO add_documents completed. total time taken: 0.094s.
# 2022-12-29 21:56:53,380 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,448 logger:'marqo' INFO add_documents roundtrip: took 0.068s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:53,449 logger:'marqo' INFO add_documents Marqo index: took 0.065s for Marqo to process & index 1 docs (server unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:53,449 logger:'marqo' INFO add_documents completed. total time taken: 0.069s.
# 2022-12-29 21:56:53,449 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,521 logger:'marqo' INFO add_documents roundtrip: took 0.072s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.072s per doc.
# 2022-12-29 21:56:53,522 logger:'marqo' INFO add_documents Marqo index: took 0.069s for Marqo to process & index 1 docs (server unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:53,522 logger:'marqo' INFO add_documents completed. total time taken: 0.073s.
# 2022-12-29 21:56:53,522 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,592 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 21:56:53,592 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:53,592 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 21:56:53,593 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,672 logger:'marqo' INFO add_documents roundtrip: took 0.079s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.079s per doc.
# 2022-12-29 21:56:53,672 logger:'marqo' INFO add_documents Marqo index: took 0.076s for Marqo to process & index 1 docs (server unbatched), for an average of 0.076s per doc.
# 2022-12-29 21:56:53,673 logger:'marqo' INFO add_documents completed. total time taken: 0.080s.
# 2022-12-29 21:56:53,673 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,738 logger:'marqo' INFO add_documents roundtrip: took 0.065s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:53,739 logger:'marqo' INFO add_documents Marqo index: took 0.062s for Marqo to process & index 1 docs (server unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:53,739 logger:'marqo' INFO add_documents completed. total time taken: 0.066s.
# 2022-12-29 21:56:53,739 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,796 logger:'marqo' INFO add_documents roundtrip: took 0.056s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.056s per doc.
# 2022-12-29 21:56:53,796 logger:'marqo' INFO add_documents Marqo index: took 0.053s for Marqo to process & index 1 docs (server unbatched), for an average of 0.053s per doc.
# 2022-12-29 21:56:53,797 logger:'marqo' INFO add_documents completed. total time taken: 0.057s.
# 2022-12-29 21:56:53,797 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,882 logger:'marqo' INFO add_documents roundtrip: took 0.084s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.084s per doc.
# 2022-12-29 21:56:53,882 logger:'marqo' INFO add_documents Marqo index: took 0.081s for Marqo to process & index 1 docs (server unbatched), for an average of 0.081s per doc.
# 2022-12-29 21:56:53,883 logger:'marqo' INFO add_documents completed. total time taken: 0.085s.
# 2022-12-29 21:56:53,883 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:53,957 logger:'marqo' INFO add_documents roundtrip: took 0.074s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.074s per doc.
# 2022-12-29 21:56:53,957 logger:'marqo' INFO add_documents Marqo index: took 0.071s for Marqo to process & index 1 docs (server unbatched), for an average of 0.071s per doc.
# 2022-12-29 21:56:53,958 logger:'marqo' INFO add_documents completed. total time taken: 0.075s.
# 2022-12-29 21:56:53,958 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,024 logger:'marqo' INFO add_documents roundtrip: took 0.065s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:54,024 logger:'marqo' INFO add_documents Marqo index: took 0.062s for Marqo to process & index 1 docs (server unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:54,025 logger:'marqo' INFO add_documents completed. total time taken: 0.067s.
# 2022-12-29 21:56:54,025 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,104 logger:'marqo' INFO add_documents roundtrip: took 0.079s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.079s per doc.
# 2022-12-29 21:56:54,105 logger:'marqo' INFO add_documents Marqo index: took 0.076s for Marqo to process & index 1 docs (server unbatched), for an average of 0.076s per doc.
# 2022-12-29 21:56:54,105 logger:'marqo' INFO add_documents completed. total time taken: 0.080s.
# 2022-12-29 21:56:54,105 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,166 logger:'marqo' INFO add_documents roundtrip: took 0.060s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:54,166 logger:'marqo' INFO add_documents Marqo index: took 0.058s for Marqo to process & index 1 docs (server unbatched), for an average of 0.058s per doc.
# 2022-12-29 21:56:54,167 logger:'marqo' INFO add_documents completed. total time taken: 0.061s.
# 2022-12-29 21:56:54,167 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,232 logger:'marqo' INFO add_documents roundtrip: took 0.065s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:54,233 logger:'marqo' INFO add_documents Marqo index: took 0.062s for Marqo to process & index 1 docs (server unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:54,233 logger:'marqo' INFO add_documents completed. total time taken: 0.066s.
# 2022-12-29 21:56:54,233 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,297 logger:'marqo' INFO add_documents roundtrip: took 0.063s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:54,297 logger:'marqo' INFO add_documents Marqo index: took 0.059s for Marqo to process & index 1 docs (server unbatched), for an average of 0.059s per doc.
# 2022-12-29 21:56:54,297 logger:'marqo' INFO add_documents completed. total time taken: 0.064s.
# 2022-12-29 21:56:54,298 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,361 logger:'marqo' INFO add_documents roundtrip: took 0.063s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:54,361 logger:'marqo' INFO add_documents Marqo index: took 0.060s for Marqo to process & index 1 docs (server unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:54,362 logger:'marqo' INFO add_documents completed. total time taken: 0.064s.
# 2022-12-29 21:56:54,362 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,481 logger:'marqo' INFO add_documents roundtrip: took 0.119s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.119s per doc.
# 2022-12-29 21:56:54,481 logger:'marqo' INFO add_documents Marqo index: took 0.116s for Marqo to process & index 1 docs (server unbatched), for an average of 0.116s per doc.
# 2022-12-29 21:56:54,481 logger:'marqo' INFO add_documents completed. total time taken: 0.120s.
# 2022-12-29 21:56:54,482 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,542 logger:'marqo' INFO add_documents roundtrip: took 0.060s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.060s per doc.
# 2022-12-29 21:56:54,543 logger:'marqo' INFO add_documents Marqo index: took 0.057s for Marqo to process & index 1 docs (server unbatched), for an average of 0.057s per doc.
# 2022-12-29 21:56:54,543 logger:'marqo' INFO add_documents completed. total time taken: 0.061s.
# 2022-12-29 21:56:54,543 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,633 logger:'marqo' INFO add_documents roundtrip: took 0.089s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.089s per doc.
# 2022-12-29 21:56:54,633 logger:'marqo' INFO add_documents Marqo index: took 0.086s for Marqo to process & index 1 docs (server unbatched), for an average of 0.086s per doc.
# 2022-12-29 21:56:54,633 logger:'marqo' INFO add_documents completed. total time taken: 0.090s.
# 2022-12-29 21:56:54,634 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,707 logger:'marqo' INFO add_documents roundtrip: took 0.073s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.073s per doc.
# 2022-12-29 21:56:54,708 logger:'marqo' INFO add_documents Marqo index: took 0.070s for Marqo to process & index 1 docs (server unbatched), for an average of 0.070s per doc.
# 2022-12-29 21:56:54,708 logger:'marqo' INFO add_documents completed. total time taken: 0.074s.
# 2022-12-29 21:56:54,709 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,790 logger:'marqo' INFO add_documents roundtrip: took 0.082s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.082s per doc.
# 2022-12-29 21:56:54,791 logger:'marqo' INFO add_documents Marqo index: took 0.078s for Marqo to process & index 1 docs (server unbatched), for an average of 0.078s per doc.
# 2022-12-29 21:56:54,791 logger:'marqo' INFO add_documents completed. total time taken: 0.083s.
# 2022-12-29 21:56:54,792 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,871 logger:'marqo' INFO add_documents roundtrip: took 0.079s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.079s per doc.
# 2022-12-29 21:56:54,871 logger:'marqo' INFO add_documents Marqo index: took 0.075s for Marqo to process & index 1 docs (server unbatched), for an average of 0.075s per doc.
# 2022-12-29 21:56:54,872 logger:'marqo' INFO add_documents completed. total time taken: 0.080s.
# 2022-12-29 21:56:54,872 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:54,945 logger:'marqo' INFO add_documents roundtrip: took 0.073s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.073s per doc.
# 2022-12-29 21:56:54,946 logger:'marqo' INFO add_documents Marqo index: took 0.070s for Marqo to process & index 1 docs (server unbatched), for an average of 0.070s per doc.
# 2022-12-29 21:56:54,946 logger:'marqo' INFO add_documents completed. total time taken: 0.074s.
# 2022-12-29 21:56:54,947 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,012 logger:'marqo' INFO add_documents roundtrip: took 0.065s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.065s per doc.
# 2022-12-29 21:56:55,013 logger:'marqo' INFO add_documents Marqo index: took 0.062s for Marqo to process & index 1 docs (server unbatched), for an average of 0.062s per doc.
# 2022-12-29 21:56:55,013 logger:'marqo' INFO add_documents completed. total time taken: 0.066s.
# 2022-12-29 21:56:55,013 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,090 logger:'marqo' INFO add_documents roundtrip: took 0.076s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.076s per doc.
# 2022-12-29 21:56:55,091 logger:'marqo' INFO add_documents Marqo index: took 0.072s for Marqo to process & index 1 docs (server unbatched), for an average of 0.072s per doc.
# 2022-12-29 21:56:55,091 logger:'marqo' INFO add_documents completed. total time taken: 0.077s.
# 2022-12-29 21:56:55,091 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,173 logger:'marqo' INFO add_documents roundtrip: took 0.081s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.081s per doc.
# 2022-12-29 21:56:55,173 logger:'marqo' INFO add_documents Marqo index: took 0.077s for Marqo to process & index 1 docs (server unbatched), for an average of 0.077s per doc.
# 2022-12-29 21:56:55,174 logger:'marqo' INFO add_documents completed. total time taken: 0.082s.
# 2022-12-29 21:56:55,174 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,245 logger:'marqo' INFO add_documents roundtrip: took 0.071s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.071s per doc.
# 2022-12-29 21:56:55,246 logger:'marqo' INFO add_documents Marqo index: took 0.068s for Marqo to process & index 1 docs (server unbatched), for an average of 0.068s per doc.
# 2022-12-29 21:56:55,246 logger:'marqo' INFO add_documents completed. total time taken: 0.072s.
# 2022-12-29 21:56:55,246 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,326 logger:'marqo' INFO add_documents roundtrip: took 0.079s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.079s per doc.
# 2022-12-29 21:56:55,326 logger:'marqo' INFO add_documents Marqo index: took 0.076s for Marqo to process & index 1 docs (server unbatched), for an average of 0.076s per doc.
# 2022-12-29 21:56:55,327 logger:'marqo' INFO add_documents completed. total time taken: 0.080s.
# 2022-12-29 21:56:55,327 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,393 logger:'marqo' INFO add_documents roundtrip: took 0.066s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.066s per doc.
# 2022-12-29 21:56:55,394 logger:'marqo' INFO add_documents Marqo index: took 0.063s for Marqo to process & index 1 docs (server unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:55,394 logger:'marqo' INFO add_documents completed. total time taken: 0.067s.
# 2022-12-29 21:56:55,395 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 21:56:55,458 logger:'marqo' INFO add_documents roundtrip: took 0.063s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.063s per doc.
# 2022-12-29 21:56:55,459 logger:'marqo' INFO add_documents Marqo index: took 0.059s for Marqo to process & index 1 docs (server unbatched), for an average of 0.059s per doc.
# 2022-12-29 21:56:55,459 logger:'marqo' INFO add_documents completed. total time taken: 0.064s.
# 2022-12-29 21:56:55,459 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# ...
# 2022-12-29 22:00:34,967 logger:'marqo' INFO add_documents completed. total time taken: 0.079s.
# 2022-12-29 22:00:34,968 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,021 logger:'marqo' INFO add_documents roundtrip: took 0.053s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.053s per doc.
# 2022-12-29 22:00:35,021 logger:'marqo' INFO add_documents Marqo index: took 0.050s for Marqo to process & index 1 docs (server unbatched), for an average of 0.050s per doc.
# 2022-12-29 22:00:35,022 logger:'marqo' INFO add_documents completed. total time taken: 0.054s.
# 2022-12-29 22:00:35,022 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,160 logger:'marqo' INFO add_documents roundtrip: took 0.138s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.138s per doc.
# 2022-12-29 22:00:35,160 logger:'marqo' INFO add_documents Marqo index: took 0.135s for Marqo to process & index 1 docs (server unbatched), for an average of 0.135s per doc.
# 2022-12-29 22:00:35,161 logger:'marqo' INFO add_documents completed. total time taken: 0.139s.
# 2022-12-29 22:00:35,161 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,215 logger:'marqo' INFO add_documents roundtrip: took 0.054s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.054s per doc.
# 2022-12-29 22:00:35,215 logger:'marqo' INFO add_documents Marqo index: took 0.051s for Marqo to process & index 1 docs (server unbatched), for an average of 0.051s per doc.
# 2022-12-29 22:00:35,216 logger:'marqo' INFO add_documents completed. total time taken: 0.055s.
# 2022-12-29 22:00:35,216 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,266 logger:'marqo' INFO add_documents roundtrip: took 0.049s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.049s per doc.
# 2022-12-29 22:00:35,266 logger:'marqo' INFO add_documents Marqo index: took 0.047s for Marqo to process & index 1 docs (server unbatched), for an average of 0.047s per doc.
# 2022-12-29 22:00:35,266 logger:'marqo' INFO add_documents completed. total time taken: 0.050s.
# 2022-12-29 22:00:35,267 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,320 logger:'marqo' INFO add_documents roundtrip: took 0.053s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.053s per doc.
# 2022-12-29 22:00:35,321 logger:'marqo' INFO add_documents Marqo index: took 0.051s for Marqo to process & index 1 docs (server unbatched), for an average of 0.051s per doc.
# 2022-12-29 22:00:35,321 logger:'marqo' INFO add_documents completed. total time taken: 0.054s.
# 2022-12-29 22:00:35,321 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,392 logger:'marqo' INFO add_documents roundtrip: took 0.070s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.070s per doc.
# 2022-12-29 22:00:35,392 logger:'marqo' INFO add_documents Marqo index: took 0.067s for Marqo to process & index 1 docs (server unbatched), for an average of 0.067s per doc.
# 2022-12-29 22:00:35,393 logger:'marqo' INFO add_documents completed. total time taken: 0.071s.
# 2022-12-29 22:00:35,393 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,474 logger:'marqo' INFO add_documents roundtrip: took 0.081s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.081s per doc.
# 2022-12-29 22:00:35,475 logger:'marqo' INFO add_documents Marqo index: took 0.078s for Marqo to process & index 1 docs (server unbatched), for an average of 0.078s per doc.
# 2022-12-29 22:00:35,475 logger:'marqo' INFO add_documents completed. total time taken: 0.082s.
# 2022-12-29 22:00:35,475 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,526 logger:'marqo' INFO add_documents roundtrip: took 0.050s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.050s per doc.
# 2022-12-29 22:00:35,526 logger:'marqo' INFO add_documents Marqo index: took 0.047s for Marqo to process & index 1 docs (server unbatched), for an average of 0.047s per doc.
# 2022-12-29 22:00:35,526 logger:'marqo' INFO add_documents completed. total time taken: 0.051s.
# 2022-12-29 22:00:35,527 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,575 logger:'marqo' INFO add_documents roundtrip: took 0.048s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.048s per doc.
# 2022-12-29 22:00:35,576 logger:'marqo' INFO add_documents Marqo index: took 0.046s for Marqo to process & index 1 docs (server unbatched), for an average of 0.046s per doc.
# 2022-12-29 22:00:35,576 logger:'marqo' INFO add_documents completed. total time taken: 0.049s.
# 2022-12-29 22:00:35,576 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,636 logger:'marqo' INFO add_documents roundtrip: took 0.060s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.060s per doc.
# 2022-12-29 22:00:35,637 logger:'marqo' INFO add_documents Marqo index: took 0.057s for Marqo to process & index 1 docs (server unbatched), for an average of 0.057s per doc.
# 2022-12-29 22:00:35,637 logger:'marqo' INFO add_documents completed. total time taken: 0.060s.
# 2022-12-29 22:00:35,637 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,701 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 22:00:35,702 logger:'marqo' INFO add_documents Marqo index: took 0.061s for Marqo to process & index 1 docs (server unbatched), for an average of 0.061s per doc.
# 2022-12-29 22:00:35,702 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 22:00:35,702 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,767 logger:'marqo' INFO add_documents roundtrip: took 0.064s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.064s per doc.
# 2022-12-29 22:00:35,767 logger:'marqo' INFO add_documents Marqo index: took 0.061s for Marqo to process & index 1 docs (server unbatched), for an average of 0.061s per doc.
# 2022-12-29 22:00:35,768 logger:'marqo' INFO add_documents completed. total time taken: 0.065s.
# 2022-12-29 22:00:35,768 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,854 logger:'marqo' INFO add_documents roundtrip: took 0.086s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.086s per doc.
# 2022-12-29 22:00:35,855 logger:'marqo' INFO add_documents Marqo index: took 0.083s for Marqo to process & index 1 docs (server unbatched), for an average of 0.083s per doc.
# 2022-12-29 22:00:35,855 logger:'marqo' INFO add_documents completed. total time taken: 0.087s.
# 2022-12-29 22:00:35,855 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,923 logger:'marqo' INFO add_documents roundtrip: took 0.068s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.068s per doc.
# 2022-12-29 22:00:35,924 logger:'marqo' INFO add_documents Marqo index: took 0.065s for Marqo to process & index 1 docs (server unbatched), for an average of 0.065s per doc.
# 2022-12-29 22:00:35,924 logger:'marqo' INFO add_documents completed. total time taken: 0.069s.
# 2022-12-29 22:00:35,924 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:35,975 logger:'marqo' INFO add_documents roundtrip: took 0.050s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.050s per doc.
# 2022-12-29 22:00:35,976 logger:'marqo' INFO add_documents Marqo index: took 0.048s for Marqo to process & index 1 docs (server unbatched), for an average of 0.048s per doc.
# 2022-12-29 22:00:35,976 logger:'marqo' INFO add_documents completed. total time taken: 0.051s.
# 2022-12-29 22:00:35,976 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,021 logger:'marqo' INFO add_documents roundtrip: took 0.045s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.045s per doc.
# 2022-12-29 22:00:36,022 logger:'marqo' INFO add_documents Marqo index: took 0.042s for Marqo to process & index 1 docs (server unbatched), for an average of 0.042s per doc.
# 2022-12-29 22:00:36,022 logger:'marqo' INFO add_documents completed. total time taken: 0.046s.
# 2022-12-29 22:00:36,022 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,070 logger:'marqo' INFO add_documents roundtrip: took 0.047s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.047s per doc.
# 2022-12-29 22:00:36,071 logger:'marqo' INFO add_documents Marqo index: took 0.045s for Marqo to process & index 1 docs (server unbatched), for an average of 0.045s per doc.
# 2022-12-29 22:00:36,071 logger:'marqo' INFO add_documents completed. total time taken: 0.048s.
# 2022-12-29 22:00:36,071 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,132 logger:'marqo' INFO add_documents roundtrip: took 0.060s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.060s per doc.
# 2022-12-29 22:00:36,132 logger:'marqo' INFO add_documents Marqo index: took 0.058s for Marqo to process & index 1 docs (server unbatched), for an average of 0.058s per doc.
# 2022-12-29 22:00:36,132 logger:'marqo' INFO add_documents completed. total time taken: 0.061s.
# 2022-12-29 22:00:36,133 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,202 logger:'marqo' INFO add_documents roundtrip: took 0.069s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.069s per doc.
# 2022-12-29 22:00:36,202 logger:'marqo' INFO add_documents Marqo index: took 0.066s for Marqo to process & index 1 docs (server unbatched), for an average of 0.066s per doc.
# 2022-12-29 22:00:36,203 logger:'marqo' INFO add_documents completed. total time taken: 0.070s.
# 2022-12-29 22:00:36,203 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,275 logger:'marqo' INFO add_documents roundtrip: took 0.072s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.072s per doc.
# 2022-12-29 22:00:36,275 logger:'marqo' INFO add_documents Marqo index: took 0.069s for Marqo to process & index 1 docs (server unbatched), for an average of 0.069s per doc.
# 2022-12-29 22:00:36,276 logger:'marqo' INFO add_documents completed. total time taken: 0.073s.
# 2022-12-29 22:00:36,276 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,338 logger:'marqo' INFO add_documents roundtrip: took 0.062s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.062s per doc.
# 2022-12-29 22:00:36,339 logger:'marqo' INFO add_documents Marqo index: took 0.059s for Marqo to process & index 1 docs (server unbatched), for an average of 0.059s per doc.
# 2022-12-29 22:00:36,339 logger:'marqo' INFO add_documents completed. total time taken: 0.063s.
# 2022-12-29 22:00:36,339 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,384 logger:'marqo' INFO add_documents roundtrip: took 0.044s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.044s per doc.
# 2022-12-29 22:00:36,384 logger:'marqo' INFO add_documents Marqo index: took 0.041s for Marqo to process & index 1 docs (server unbatched), for an average of 0.041s per doc.
# 2022-12-29 22:00:36,384 logger:'marqo' INFO add_documents completed. total time taken: 0.045s.
# 2022-12-29 22:00:36,385 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,433 logger:'marqo' INFO add_documents roundtrip: took 0.049s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.049s per doc.
# 2022-12-29 22:00:36,434 logger:'marqo' INFO add_documents Marqo index: took 0.046s for Marqo to process & index 1 docs (server unbatched), for an average of 0.046s per doc.
# 2022-12-29 22:00:36,434 logger:'marqo' INFO add_documents completed. total time taken: 0.050s.
# 2022-12-29 22:00:36,435 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,479 logger:'marqo' INFO add_documents roundtrip: took 0.044s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.044s per doc.
# 2022-12-29 22:00:36,479 logger:'marqo' INFO add_documents Marqo index: took 0.041s for Marqo to process & index 1 docs (server unbatched), for an average of 0.041s per doc.
# 2022-12-29 22:00:36,480 logger:'marqo' INFO add_documents completed. total time taken: 0.045s.
# 2022-12-29 22:00:36,480 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,552 logger:'marqo' INFO add_documents roundtrip: took 0.072s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.072s per doc.
# 2022-12-29 22:00:36,552 logger:'marqo' INFO add_documents Marqo index: took 0.068s for Marqo to process & index 1 docs (server unbatched), for an average of 0.068s per doc.
# 2022-12-29 22:00:36,553 logger:'marqo' INFO add_documents completed. total time taken: 0.073s.
# 2022-12-29 22:00:36,553 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,604 logger:'marqo' INFO add_documents roundtrip: took 0.051s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.051s per doc.
# 2022-12-29 22:00:36,605 logger:'marqo' INFO add_documents Marqo index: took 0.048s for Marqo to process & index 1 docs (server unbatched), for an average of 0.048s per doc.
# 2022-12-29 22:00:36,605 logger:'marqo' INFO add_documents completed. total time taken: 0.052s.
# 2022-12-29 22:00:36,605 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,672 logger:'marqo' INFO add_documents roundtrip: took 0.066s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.066s per doc.
# 2022-12-29 22:00:36,672 logger:'marqo' INFO add_documents Marqo index: took 0.064s for Marqo to process & index 1 docs (server unbatched), for an average of 0.064s per doc.
# 2022-12-29 22:00:36,673 logger:'marqo' INFO add_documents completed. total time taken: 0.067s.
# 2022-12-29 22:00:36,673 logger:'marqo' INFO add_documents pre-processing: took 0.000s for 1 docs, for an average of 0.000s per doc.
# 2022-12-29 22:00:36,762 logger:'marqo' INFO add_documents roundtrip: took 0.089s to send 1 docs to Marqo (roundtrip, unbatched), for an average of 0.089s per doc.
# 2022-12-29 22:00:36,763 logger:'marqo' INFO add_documents Marqo index: took 0.086s for Marqo to process & index 1 docs (server unbatched), for an average of 0.086s per doc.
# 2022-12-29 22:00:36,763 logger:'marqo' INFO add_documents completed. total time taken: 0.090s.

# %% [markdown]
# # Sitemap Assay
#
# The start of a simple notebook that could hosted for peeopl to test out their sitemaps (and robots.txt) files with.
#
# References:
# * [AdvTools](https://advertools.readthedocs.io/en/master/advertools.sitemaps.html)
# * [Sitemap viz](https://www.ayima.com/us/insights/analytics-and-cro/how-to-visualize-an-xml-sitemap-using-python.html)
#
# ## Notes
#
# Some commands of note
#
#
# You can parse sitemaps from the command line with:
# ```
#  curl -s https://geoconnex.us/sitemap/nhdplusv2/huc12pp/huc12pp__1.xml |  grep -oP '<loc>\K[^<]*'
#  ```
#
#
#  You could then use curl with an accept header set to test a rsource.
#
#  ```
#  curl -LH "Accept: application/ld+json"   https://geoconnex.us/nhdplusv2/huc12/030601020107
#  ```

# %%
import advertools as adv
import json
import requests
from bs4 import BeautifulSoup
import urllib.request

# %%
# %%time 

# load the sitemap into a dataframe via advertools
iow_sitemap = adv.sitemap_to_df('http://www.cen.ulaval.ca/nordicanad/sitemap.xml')
# iow_sitemap = adv.sitemap_to_df('http://data.marine.ie/geonetwork/srv/eng/portal.sitemap')
# iow_sitemap = adv.sitemap_to_df('https://edmo.seadatanet.org/sitemap.xml')
# iow_sitemap = adv.sitemap_to_df('https://geoconnex.us/sitemap.xml')
# Out:
# 2021-12-17 11:53:25,753 | INFO | sitemaps.py:419 | sitemap_to_df | Getting http://www.cen.ulaval.ca/nordicanad/sitemap.xml
# CPU times: user 11.5 ms, sys: 2.74 ms, total: 14.3 ms
# Wall time: 307 ms

# %%
iow_sitemap.info()
iow_sitemap.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   loc                    80 non-null     object
#  1   sitemap                80 non-null     object
#  2   etag                   80 non-null     object
#  3   sitemap_last_modified  80 non-null     datetime64[ns, UTC]
#  4   sitemap_size_mb        80 non-null     float64
#  5   download_date          80 non-null     datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](2), float64(1), object(3)
# memory usage: 3.9+ KB
#                                                  loc  \
# 0  https://www.cen.ulaval.ca/nordicanad/dpage.asp...
# 1  https://www.cen.ulaval.ca/nordicanad/dpage.asp...
# 2  https://www.cen.ulaval.ca/nordicanad/dpage.asp...
# 3  https://www.cen.ulaval.ca/nordicanad/dpage.asp...
# 4  https://www.cen.ulaval.ca/nordicanad/dpage.asp...
#
#                                            sitemap               etag  \
# 0  http://www.cen.ulaval.ca/nordicanad/sitemap.xml  80909a5091d5d71:0
# 1  http://www.cen.ulaval.ca/nordicanad/sitemap.xml  80909a5091d5d71:0
# 2  http://www.cen.ulaval.ca/nordicanad/sitemap.xml  80909a5091d5d71:0
# 3  http://www.cen.ulaval.ca/nordicanad/sitemap.xml  80909a5091d5d71:0
# 4  http://www.cen.ulaval.ca/nordicanad/sitemap.xml  80909a5091d5d71:0
#
#       sitemap_last_modified  sitemap_size_mb                    download_date
# 0 2021-11-09 17:43:33+00:00         0.007738 2021-12-17 17:53:25.757873+00:00
# 1 2021-11-09 17:43:33+00:00         0.007738 2021-12-17 17:53:25.757873+00:00
# 2 2021-11-09 17:43:33+00:00         0.007738 2021-12-17 17:53:25.757873+00:00
# 3 2021-11-09 17:43:33+00:00         0.007738 2021-12-17 17:53:25.757873+00:00
# 4 2021-11-09 17:43:33+00:00         0.007738 2021-12-17 17:53:25.757873+00:00

# %% [markdown]
# ## Unique Sitemaps URLs and resource URLs in IoW
#
# We can quickly grabe the unique URLs from the sitemap column and see how many unique sitemap.xml files we are working with

# %%
usm = iow_sitemap.sitemap.unique()
uloc = iow_sitemap["loc"].unique()
print("{} unique sitemap XML file(s) pointing to {} unique resource(s).".format(len(usm), len(uloc)))
# Out:
# 1 unique sitemap XML file(s) pointing to 80 unique resource(s).

# %% [markdown]
# ## Analyzing the URLs
#
# We can also dive into the URL structure for the resources a bit.

# %%
# Break down all the URL into theor path parts
urldf = adv.url_to_df(list(iow_sitemap['loc']))
urldf.head()
# Out:
#                                                  url scheme  \
# 0  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 1  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 2  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 3  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 4  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
#
#               netloc                    path                         query  \
# 0  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=44985SL-8F203FD3ACCD4138
# 1  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45039SL-EE76C1BDAADC4890
# 2  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45048SL-4708BCCDFA124359
# 3  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45057SL-EADE4434146946A7
# 4  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45111SL-B5D073186F274136
#
#   fragment       dir_1       dir_2                 query_doi
# 0           nordicanad  dpage.aspx  44985SL-8F203FD3ACCD4138
# 1           nordicanad  dpage.aspx  45039SL-EE76C1BDAADC4890
# 2           nordicanad  dpage.aspx  45048SL-4708BCCDFA124359
# 3           nordicanad  dpage.aspx  45057SL-EADE4434146946A7
# 4           nordicanad  dpage.aspx  45111SL-B5D073186F274136

# %%
#set the column sof interest
coi = "query"

# %%
# We can not aggregate at various levels...   
e4 = urldf[coi].value_counts()
e4.rename_axis("sources")

e4df = e4.to_frame()
e4df.head(len(e4))
# Out:
#                               query
# doi=44985SL-8F203FD3ACCD4138      1
# doi=45039SL-EE76C1BDAADC4890      1
# doi=45591AW-F9B906CC647948E0      1
# doi=45588CE-5A12A84DFAAF4D36      1
# doi=45585XD-DE2479484D664DE8      1
# ...                             ...
# doi=45436CE-0E0A89CB98C148F4      1
# doi=45427AD-06F05740704B4CA3      1
# doi=45418AD-AF6A8064C702444B      1
# doi=45409XD-79A199B76BCC4110      1
# doi=45690CE-5714F25354274D62      1
#
# [80 rows x 1 columns]

# %% [markdown]
# ## Plot sitemap diversity
#
# This following section is only of value in cases where is a diveristy of path names above the final resource entry in a sitemap.
# Otherwise these sections provide no insight.

# %%
# If we have lots of values above, then we can sum lower end ones into an "others" category.
# This is not needed if the breakdown is small or 1 above the final resource entry in a sitemap.
# With a little trial and error we can see the cutoff for a chart 
breakat = 1
ts = e4df.tail(breakat)[coi].sum()
e4topdf = e4df# [e4df[coi]]  # work in using breakat to get this
e4topdf.reset_index(inplace = True, drop = False)
e4topdf.rename(columns={'index': 'source', coi:'count'},  inplace = True)

t = e4topdf.append({'source':'other', 'count':ts}, ignore_index=True) 
t.head(10)
# Out:
#                          source  count
# 0  doi=44985SL-8F203FD3ACCD4138      1
# 1  doi=45039SL-EE76C1BDAADC4890      1
# 2  doi=45591AW-F9B906CC647948E0      1
# 3  doi=45588CE-5A12A84DFAAF4D36      1
# 4  doi=45585XD-DE2479484D664DE8      1
# 5  doi=45582CE-9C59423742194D52      1
# 6  doi=45579CE-2262D40C8DFE49F0      1
# 7  doi=45576CE-75E2938693214B96      1
# 8  doi=45573XD-28DD57D553F14BF0      1
# 9  doi=45570CE-2D00DCA728074FA7      1

# %%
import matplotlib.pyplot as plt
from pandas.plotting import table

plt.figure(figsize=(30,10))

# plot chart
ax1 = plt.subplot(121, aspect='equal')
t.plot(kind='pie', y = 'count', ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=t['source'], legend = False, fontsize=12)

# # plot table
# ax2 = plt.subplot(122,  aspect='equal')
# plt.axis('off')
# tbl = table(ax2, t, loc='center')
# tbl.auto_set_font_size(False)
# tbl.set_fontsize(12)
# plt.show()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
e4sort = e4.sort_values(ascending=True)
plot = e4sort.plot.bar(y='dir_4',legend=True, grid=True, logy = True, figsize=(10, 10))

# %% [markdown]
# ## Sample and test sitemap entries

# %%
# sample the previously generated url data frame
sample_size = 5
sample_df = urldf.groupby("dir_1").sample(n=sample_size, random_state=1, replace=True)

# %%
sample_df.head()
# Out:
#                                                   url scheme  \
# 37  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 12  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 72  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 9   https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
# 75  https://www.cen.ulaval.ca/nordicanad/dpage.asp...  https
#
#                netloc                    path                         query  \
# 37  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45505SL-528A7C505494428A
# 12  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45219SL-2B4081DF20FC42C8
# 72  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45648CE-1A9AB63DFF91440B
# 9   www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45192SL-7C87131DC13244B8
# 75  www.cen.ulaval.ca  /nordicanad/dpage.aspx  doi=45657CE-4AA8A7A640934B9E
#
#    fragment       dir_1       dir_2                 query_doi
# 37           nordicanad  dpage.aspx  45505SL-528A7C505494428A
# 12           nordicanad  dpage.aspx  45219SL-2B4081DF20FC42C8
# 72           nordicanad  dpage.aspx  45648CE-1A9AB63DFF91440B
# 9            nordicanad  dpage.aspx  45192SL-7C87131DC13244B8
# 75           nordicanad  dpage.aspx  45657CE-4AA8A7A640934B9E

# %%
import urllib.request
import requests

ul = sample_df["url"]

for item in ul:
    headers, code, dtype = None, None, None
    
    try:
        x = requests.get(item)
        code = x.status_code
        with urllib.request.urlopen(item) as response:
            info = response.info()
            dtype = info.get_content_type()    # -> text/html

        # headers = x.headers()
    except:
        code = "error"
        dtype = "error"
        headers = "error"
    
    print("{}: {} : {} : {}".format(code, dtype, item, headers))
# Out:
# 200: text/html : https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=45505SL-528A7C505494428A : None
# 200: text/html : https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=45219SL-2B4081DF20FC42C8 : None
# 200: text/html : https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=45648CE-1A9AB63DFF91440B : None
# 200: text/html : https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=45192SL-7C87131DC13244B8 : None
# 200: text/html : https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=45657CE-4AA8A7A640934B9E : None

# %%
ul = sample_df["url"]

for item in ul:
    html = urllib.request.urlopen(item).read()
    soup = BeautifulSoup(html, "html.parser")
    p = soup.find('script', {'type':'application/ld+json'})
    try:
        # print(len(p.contents))
        print(p)
        # TODO  load and see if this is valid JSON-LD
    except:
        print("no JSON-LD found, does the URL require JS execution to load the JSON-LD?")
# Out:
# <script type="application/ld+json"> {
#     "@context": "https://schema.org/",
#     "@type": "Dataset",
#     "identifier": "https://doi.org/10.5885/45505SL-528A7C505494428A",
#     "url": "https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=10.5885/45505SL-528A7C505494428A",
#     "isAccessibleForFree": true,
#     "name": "Climate station data from Nikku Island in Nunavut, Canada",
#     "alternateName": "Données de la station climatique de l'île Nikku, Nunavut , Canada",
#     "description": "Data are from Nikku Island in Nunavut, Canada. It contains data from air and ground temperatures, air humidity, solar radiation, wind speed and direction. The available datasets cover the period from 2010-2016.  The depth of the borehole is 100 cm. Data are available as: (1) recorded data; (2) daily averages; (3) monthly averages; and (4) yearly averages.",
#     "datePublished": "2020-04-01",
#     "dateModified": "2020-04-01",
#     "version": "1.0",
#     "keywords": "annuelle,yearly,Canada,climat,climate,forage,borehole,géothermique,geothermal,journalière,daily,mensuelle,monthly,moyenne,average,nord,north,nunavut,nunavut,pergélisol,permafrost,processus,processes,réseau,network,SILA,sol,ground,sol,soil,température,temperature,températures,temperatures,thermique,thermal,thermo-dynamiques,thermo-dynamical",
#     "citation": "CEN 2020. Climate station data from Nikku Island in Nunavut, Canada, v. 1.0 (2010-2016). Nordicana D64, doi: 10.5885/45505SL-528A7C505494428A.",
#     "temporalCoverage": "2010-08-02/2016-07-20",
#     "author": [
#       {
#     "@type": "Organization",
#     "name": " Centre d'études Nordiques"
#       }
#     ],
#     "variableMeasured": [
#       {
#     "@type": "PropertyValue",
#     "name": "Average air humidity",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Percentage",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577904"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Average air temperature",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577908"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Average downwelling radiation",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Watt per square meter",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577905"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Average ground temperature",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577909"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Average wind speed",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Meter per second",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577911"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Maximum air temperature",
#     "description": "The maximum is determined by selecting the highest value obtained during the observation of the last period.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577906"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Maximum wind speed",
#     "description": "The maximum is determined by selecting the highest value obtained during the observation of the last hour.",
#     "unitText": "Meter per second",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577910"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Minimum air temperature",
#     "description": "The minimum is determined by selecting the lowest value obtained during the observation of the last hour.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577907"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Sample on wind direction",
#     "description": "Sample took from the readings obtained during the last hour. The sample is taken on the 60 readings generated per hour.",
#     "unitText": "Degree",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=577903"
#       }
#     ],
#     "spatialCoverage": {"geo":[
#       {
#       "@type": "GeoCoordinates",
#       "latitude": "66.5941",
#       "longitude": "-71.5161",
#       "name": "Nikku Island (NIKKU10)"
#       }],
#      "@type": "Place" },
#     "license": "https://www.cen.ulaval.ca/nordicanad/en_modalite.aspx",
#     "publisher": { "@type": "Organization", "name": "Nordicana D", "url": "https://www.cen.ulaval.ca/nordicanad/en_index.aspx", "logo": "https://www.cen.ulaval.ca/nordicanad/images/logofloconcouleur_75pct_02.png" },
#     "provider": { "@type": "Organization", "name": "Centre d'études Nordiques (CEN)", "url": "https://www.cen.ulaval.ca/" }
# }
# </script>
# <script type="application/ld+json"> {
#     "@context": "https://schema.org/",
#     "@type": "Dataset",
#     "identifier": "https://doi.org/10.5885/45219SL-2B4081DF20FC42C8",
#     "url": "https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=10.5885/45219SL-2B4081DF20FC42C8",
#     "isAccessibleForFree": true,
#     "name": "Climate station data from the Inukjuak region in Nunavik, Quebec, Canada",
#     "alternateName": "Données des stations climatiques de la région d'Inukjuak au Nunavik, Québec, Canada",
#     "description": "Data are from the Inukjuak region in Nunavik, Quebec, Canada. It contains data from air temperatures. The available datasets cover the period from 2008-2019. Data are available as: (1) recorded data; (2) daily averages; (3) monthly averages; and (4) yearly averages.",
#     "datePublished": "2013-06-25",
#     "dateModified": "2020-01-13",
#     "version": "1.5",
#     "keywords": "air,air,annuelle,yearly,baie,bay,Canada,cote,coast,côte,coast,cotier,coastal,côtier,coastal,hudson,hudson,inukjuaq,inukjuaq,journalière,daily,maximum,maximum,mensuelle,monthly,minimum,minimum,moyenne,average,nunavik,nunavik,québec,quebec,température,temperature,températures,temperatures,village,village",
#     "citation": "Sarrazin, D., Allard, M. 2020. Climate station data from the Inukjuak region in Nunavik, Quebec, Canada, v. 1.5 (2008-2019). Nordicana D13, doi: 10.5885/45219SL-2B4081DF20FC42C8.",
#     "temporalCoverage": "2008-10-07/2019-10-26",
#     "author": [
#       {
#     "@type": "Person",
#     "name": "Denis Sarrazin",
#     "givenName": "Denis ",
#     "familyName": "Sarrazin",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études Nordiques"
#                   }
#       },
#       {
#     "@type": "Person",
#     "name": "Michel Allard",
#     "givenName": "Michel ",
#     "familyName": "Allard",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études Nordiques"
#                   }
#       }
#     ],
#     "variableMeasured": [
#       {
#     "@type": "PropertyValue",
#     "name": "Average air temperature",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=590048"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Maximum air temperature",
#     "description": "The maximum is determined by selecting the highest value obtained during the observation of the last period.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=590050"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Minimum air temperature",
#     "description": "The minimum is determined by selecting the lowest value obtained during the observation of the last period.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=590049"
#       }
#     ],
#     "spatialCoverage": {"geo":[
#       {
#       "@type": "GeoCoordinates",
#       "latitude": "58.4688",
#       "longitude": "-78.0843",
#       "name": "Inukjuak, F2 (INUK_F2)"
#       }],
#      "@type": "Place" },
#     "license": "https://www.cen.ulaval.ca/nordicanad/en_modalite.aspx",
#     "publisher": { "@type": "Organization", "name": "Nordicana D", "url": "https://www.cen.ulaval.ca/nordicanad/en_index.aspx", "logo": "https://www.cen.ulaval.ca/nordicanad/images/logofloconcouleur_75pct_02.png" },
#     "provider": { "@type": "Organization", "name": "Centre d'études Nordiques (CEN)", "url": "https://www.cen.ulaval.ca/" }
# }
# </script>
# <script type="application/ld+json"> {
#     "@context": "https://schema.org/",
#     "@type": "Dataset",
#     "identifier": "https://doi.org/10.5885/45648CE-1A9AB63DFF91440B",
#     "url": "https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=10.5885/45648CE-1A9AB63DFF91440B",
#     "isAccessibleForFree": true,
#     "name": "Dynamics of ice cover over a far northern lake : Direct observations of Ward Hunt Lake, Canadian High Arctic, by automated camera.",
#     "alternateName": "Dynamique du couvert de glace d’un lac dans l'extrême nord : Observations directes du lac Ward Hunt, haut arctique canadien, par caméra automatisée.",
#     "description": "Long-term monitoring of lakes and fjords on the northern coast of Ellesmere Island, Nunavut, provides information on the effects of climate change on these ecosystems and their seasonal and interannual dynamics.  Lake ice cover is a sentinel variable with controlling effects on lake ecosystems, and it is especially sensitive to climate change. This dataset of ice imagery for Ward Hunt Lake (Ward Hunt Island) covers the period 2016-2019 and is a contribution to the NEIGE program (Northern Ellesmere Island in the Global Environment). Weather-resistant time-lapse cameras were installed on metal supports (rods) overlooking the lake in order to observe and document changes in the lake (ice and snow cover, water level) and its watershed (snow, vegetation, ground conditions, wildlife).  The dataset has been separated into seasonal or monthly folders to facilitate downloading; note that there was a change of  camera model and repositioning in 2017.",
#     "datePublished": "2020-04-15",
#     "dateModified": "2020-04-15",
#     "version": "1.1",
#     "keywords": "Ward Hunt Island,Ward Hunt Island,haut arctique,high Arctic,glace de lac,lake ice,changement climatique,climate change,Tuvaijuittuq,Tuvaijuittuq,Quttinirpaaq,Quttinirpaaq,neige,snow,lacs,lakes,cryosphère,cryosphere,désert polaire,polar desert",
#     "citation": "NEIGE 2020. Dynamics of ice cover over a far northern lake : Direct observations of Ward Hunt Lake, Canadian High Arctic, by automated camera., v. 1.1 (2016-2019). Nordicana D74, doi: 10.5885/45648CE-1A9AB63DFF91440B.",
#     "temporalCoverage": "2016-06-25/2019-04-21",
#     "author": [
#       {
#     "@type": "Organization",
#     "name": " NEIGE"
#       }
#     ],
#     "contributor": [
#       {
#     "@type": "Person",
#     "jobTitle": "DataCollector",
#     "name": "Paschale N. Bégin",
#     "givenName": "Paschale N.",
#     "familyName": "Bégin",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université Laval"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "Researcher",
#     "name": "Alexander I. Culley",
#     "givenName": "Alexander I.",
#     "familyName": "Culley",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université Laval"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "Researcher",
#     "name": "Daniel Fortier",
#     "givenName": "Daniel ",
#     "familyName": "Fortier",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université de Montréal"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "Researcher",
#     "name": "Sophie Larochelle",
#     "givenName": "Sophie ",
#     "familyName": "Larochelle",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'optique, photonique et laser,  Université Laval"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "DataManager",
#     "name": "Alex Matveev",
#     "givenName": "Alex ",
#     "familyName": "Matveev",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université Laval"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "DataCollector",
#     "name": "Michel Paquette",
#     "givenName": "Michel ",
#     "familyName": "Paquette",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université de Montréal"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "DataCollector",
#     "name": "Denis Sarrazin",
#     "givenName": "Denis ",
#     "familyName": "Sarrazin",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université Laval"
#                   }
#       },
#       {
#     "@type": "Person",
#     "jobTitle": "ProjectLeader",
#     "name": "Warwick F. Vincent",
#     "givenName": "Warwick F.",
#     "familyName": "Vincent",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques, Université Laval"
#                   }
#       }
#     ],
#     "variableMeasured": [
#       {
#     "@type": "PropertyValue",
#     "name": "Digitized photographs",
#     "description": "Direct observations from automated cameras.",
#     "unitText": "unitless"
#       }
#     ],
#     "measurementTechnique": [
#       "Appareil photo professionnel Reconyx PC800",
#       "Canon EOS Rebel T6i, Lens Model: EF-S18-55mm f/3.5-5.6 IS STM",
#       "Canon EOS Rebel T6i, Modèle d'objectif: EF-S18-55mm f/3.5-5.6 IS STM",
#       "Reconyx PC800 Professional camera"
#     ],
#     "spatialCoverage": {"geo":[
#       {
#       "@type": "GeoCoordinates",
#       "latitude": "83.0878",
#       "longitude": "-74.1454",
#       "name": "Ward Hunt Lake"
#       },
#       {
#       "@type": "GeoCoordinates",
#       "latitude": "83.0879",
#       "longitude": "-74.213",
#       "name": "Automated camera site"
#       }],
#      "@type": "Place" },
#     "license": "https://www.cen.ulaval.ca/nordicanad/en_modalite.aspx",
#     "publisher": { "@type": "Organization", "name": "Nordicana D", "url": "https://www.cen.ulaval.ca/nordicanad/en_index.aspx", "logo": "https://www.cen.ulaval.ca/nordicanad/images/logofloconcouleur_75pct_02.png" },
#     "provider": { "@type": "Organization", "name": "Centre d'études Nordiques (CEN)", "url": "https://www.cen.ulaval.ca/" }
# }
# </script>
# <script type="application/ld+json"> {
#     "@context": "https://schema.org/",
#     "@type": "Dataset",
#     "identifier": "https://doi.org/10.5885/45192SL-7C87131DC13244B8",
#     "url": "https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=10.5885/45192SL-7C87131DC13244B8",
#     "isAccessibleForFree": true,
#     "name": "Climate station data from the Akulivik region in Nunavik, Quebec, Canada",
#     "alternateName": "Données des stations climatiques de la région d'Akulivik au Nunavik, Québec, Canada",
#     "description": "Data are from the Akulivik region in Nunavik, Quebec, Canada. It contains data from air temperatures, wind direction and wind speed. The available datasets cover the period from 2004-2019. Data are available as: (1) recorded data; (2) daily averages; (3) monthly averages; and (4) yearly averages.",
#     "datePublished": "2013-06-25",
#     "dateModified": "2020-01-10",
#     "version": "1.5",
#     "keywords": "air,air,akulivik,akulivik,annuelle,yearly,baie,bay,Canada,cote,coast,côte,coast,cotier,coastal,côtier,coastal,direction,direction,echantillon,sample,échantillon,sample,hudson,hudson,journalière,daily,maximum,maximum,minimum,minimum,moyenne,average,nunavik,nunavik,québec,quebec,vitesse,speed,température,temperature,températures,temperatures,vent,wind,vents,winds,village,village",
#     "citation": "Sarrazin, D., Allard, M. 2020. Climate station data from the Akulivik region in Nunavik, Quebec, Canada, v. 1.5 (2004-2019). Nordicana D11, doi: 10.5885/45192SL-7C87131DC13244B8.",
#     "temporalCoverage": "2004-06-23/2019-09-25",
#     "author": [
#       {
#     "@type": "Person",
#     "name": "Denis Sarrazin",
#     "givenName": "Denis ",
#     "familyName": "Sarrazin",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études Nordiques"
#                   }
#       },
#       {
#     "@type": "Person",
#     "name": "Michel Allard",
#     "givenName": "Michel ",
#     "familyName": "Allard",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études Nordiques"
#                   }
#       }
#     ],
#     "variableMeasured": [
#       {
#     "@type": "PropertyValue",
#     "name": "Average air temperature",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=589901"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Average wind speed",
#     "description": "Average data recorded every minute for the previous period. The average is calculated by adding the measured values and then dividing the sum by the number of observations.",
#     "unitText": "Meter per second",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=589900"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Maximum air temperature",
#     "description": "The maximum is determined by selecting the highest value obtained during the observation of the last period.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=589897"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Maximum wind speed",
#     "description": "The maximum is determined by selecting the highest value obtained during the observation of the last hour.",
#     "unitText": "Meter per second",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=589899"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Minimum air temperature",
#     "description": "The minimum is determined by selecting the lowest value obtained during the observation of the last period.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=589898"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Sample on wind direction",
#     "description": "Sample took from the readings obtained during the last hour. The sample is taken on the 60 readings generated per hour.",
#     "unitText": "Degree",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=589896"
#       }
#     ],
#     "spatialCoverage": {"geo":[
#       {
#       "@type": "GeoCoordinates",
#       "latitude": "60.8174",
#       "longitude": "-78.155",
#       "name": "Akulivik, HT-162 (AKUL162)"
#       }],
#      "@type": "Place" },
#     "license": "https://www.cen.ulaval.ca/nordicanad/en_modalite.aspx",
#     "publisher": { "@type": "Organization", "name": "Nordicana D", "url": "https://www.cen.ulaval.ca/nordicanad/en_index.aspx", "logo": "https://www.cen.ulaval.ca/nordicanad/images/logofloconcouleur_75pct_02.png" },
#     "provider": { "@type": "Organization", "name": "Centre d'études Nordiques (CEN)", "url": "https://www.cen.ulaval.ca/" }
# }
# </script>
# <script type="application/ld+json"> {
#     "@context": "https://schema.org/",
#     "@type": "Dataset",
#     "identifier": "https://doi.org/10.5885/45657CE-4AA8A7A640934B9E",
#     "url": "https://www.cen.ulaval.ca/nordicanad/dpage.aspx?doi=10.5885/45657CE-4AA8A7A640934B9E",
#     "isAccessibleForFree": true,
#     "name": "Ground surface temperatures, soil properties and vegetation cover in the Narsajuaq River Valley, Nunavik, Canada",
#     "alternateName": "Températures de surface des sols, propriétés des sol et couvert végétal dans la vallées de la rivière Narsajuaq, Nunavik, Canada",
#     "description": "During the summers of 2016, 2017 and 2018, field campaigns were conducted to study ice wedges and changes in the landscape of the Narsajuaq River Valley. The data presented here mainly describe the soil characteristics (soil layers, density, water content, carbon, hydrogen and nitrogen content) of the different study sites in the valley as well as surface conditions (water, vegetation, temperature). A total of 64 holes in 16 sites were dug to study the soil layers and hundreds of thaw front depth measurements were made with a Dutch soil auger and a steel rod in the 16 sites and 10 other areas. Data about the ice wedges are not presented, but are available in Gagnon and Allard (2020).",
#     "datePublished": "2020-07-17",
#     "dateModified": "2020-07-17",
#     "version": "1.0",
#     "keywords": "Pergélisol,Permafrost,Couche active,Active layer,Couche organique,Organic layer,Masse volumique,Density,Teneur en eau,Water content,Végétation,Vegetation,Carbone,Carbon,Température de surface,Surface temperature,Sol,Soil,Nunavik,Nunavik,Narsajuaq,Narsajuaq",
#     "citation": "Gagnon, S.,Allard, M. 2020. Ground surface temperatures, soil properties and vegetation cover in the Narsajuaq River Valley, Nunavik, Canada, v. 1.0 (2016-2018). Nordicana D76, doi: 10.5885/45657CE-4AA8A7A640934B9E.",
#     "temporalCoverage": "2016-07-01/2018-08-31",
#     "author": [
#       {
#     "@type": "Person",
#     "name": "Samuel Gagnon",
#     "givenName": "Samuel ",
#     "familyName": "Gagnon",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques"
#                   }
#       },
#       {
#     "@type": "Person",
#     "name": "Michel Allard",
#     "givenName": "Michel ",
#     "familyName": "Allard",
#     "affiliation": {
#            "@type": "Organization",
#            "name": "Centre d'études nordiques"
#                   }
#       }
#     ],
#     "variableMeasured": [
#       {
#     "@type": "PropertyValue",
#     "name": "Carbon, hydrogen and nitrate content",
#     "description": "Carbon, hydrogen and nitrogen content of soil samples collected in the Narsajuaq River Valley in 2016 and 2017. The samples were collected in volumetric cylinders or from soil discs cut from drill core. After being dried at 75°C for 24h, sieved in a 1000 micron sieve, crushed and homogenized, the samples were analyzed with a LECO CHN628 analyser for carbon, hydrogen and nitrogen content.",
#     "unitText": "Percentage",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595551"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Characteristics of sites in the Narsajuaq River Valley",
#     "description": "General description of the study sites in the Narsajuaq River valley with coordinates, polygon shapes, dominant vegetation type and water saturation level at the surface. With the exception of G4, the 20 D and G sites are polygonal networks that were investigated for ice-wedge activity and morphology (see Gagnon and Allard, 2020). Also, sites D and G were studied by Kasper and Allard (2001) between 1989 and 1991, except for D11, D12, D13 and G8. These four sites are new sites established in 2017 and have not been studied as much as the other sites, explaining why they do not appear in the other datasets. For the zones, they are additional areas that were probed with a Dutch soil auger and where vegetation cover was surveyed in order to increase spatial variability in our data and obtain a better understanding of the soil characteristics of the valley. For the dominating vegetation, in the case of mixed vegetation, it's a mix of evergreen shrubs, deciduous shurbs, graminoids, forbs, mosses and sphagnum in different proportions.    Gagnon, S. and M. Allard (2020), Changes in ice-wedge activity over 25 years of climate change near Salluit, Nunavik (Northern Québec, Canada), Permafrost and Periglacial Processes, doi: 10.1002/ppp.2030.  Kasper, J.N. and M. Allard (2001), Late-Holocene climatic changes as detected by the growth and decay of ice wedges on the southern shore of Hudson Strait, northern Québec, Canada, The Holocen, doi: 10.1191/095968301680223512.",
#     "unitText": "unitless"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Organic layer thickness",
#     "description": "Organic layer thickness measured in 16 sites and 10 other areas in July/August 2017. This layer corresponds to the top organic layer before reaching the underlying mineral deposits. Measurements were made using soil profiles collected with a Dutch soil auger.",
#     "unitText": "Centimeter",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595553"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Soil density",
#     "description": "Density of soil samples collected in the Narsajuaq River Valley in 2016 and 2017. The samples were collected in volumetric cylinders (101.76 cm3) or from soil discs cut from drill cores (variable volume depending on the thickness of the disks, ~1 cm). In the laboratory, the samples were dried at 75°C for 24 hours before being weighed to obtain the dry soil density. Then, the values were obtained using the equation dry mass (g) / volume (cm3).",
#     "unitText": "Gram per cubic centimeter",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595549"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Soil surface temperature",
#     "description": "Soil surface temperature (2-3 cm) between August 2016 and August 2018 in 15 sites in the Narsajuaq River Valley. Data is recorded on an hourly or two-hourly basis depending on the data logger used. From 2016 to 2017, soil surface temperature is recorded in 6 sites and between 2017 and 2018 it is recorded in 15 sites.  Note that D4's data logger was found on the ground in 2017, which means that the data collected probably does not reflect ground surface temperature, but rather the temperature in direct sunlight. Note that the data logger at site D4  was found exposed above the surface in 2017, which means that the data collected probably does not reflect ground temperatures, but rather the temperature in direct sunlight.",
#     "unitText": "Degree Celsius",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595548"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Soil water content",
#     "description": "Soil water content of soil samples collected in the Narsajuaq River Valley in 2016 and 2017. The samples were collected in volumetric cylinders (101.76 cm3) or from soil discs cut from drill cores (variable volume depending on the thickness of the disks, ~1 cm). In the laboratory, the wet samples were dried at 75°C for 24 hours before being weighed to obtain the dry mass. Then, water content was obtained using the equation (wet mass (g) - dry mass (g)) / wet mass (g) * 100.",
#     "unitText": "Percentage",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595550"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Thaw front depth",
#     "description": "Thaw front depths measured in 16 sites and 10 other areas in July/August 2017 and August 2018. Measurements were made with a steel rod driven into the ground to refusal or with a Dutch soil auger.",
#     "unitText": "Centimeter",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595552"
#       },
#       {
#     "@type": "PropertyValue",
#     "name": "Vegetation cover",
#     "description": "Soil surface vegetative cover (%) using the following classes: deciduous shrubs, evergreen shrubs, graminoids, forbs, mosses, lichens, rock and stones, and bare soil, Sphagnum. The vegetation cover was assessed using 1x1m quadrats and an abundance cover with the following classes:  <1%, 0-5%, 5-25%, 25-50%, 50-75%, 75-100%. For sites Q1-Q5 and TA1-TA10, the quadrats were placed on tundra polygons and for sites Q6-Q8, the quadrats were in troughs between the polygons. A list of species identified in the valley is available in the supplementary documents.",
#     "unitText": "Percentage",
#     "url": "https://www.cen.ulaval.ca/nordicanad/infounitedonnees.aspx?id=595556"
#       }
#     ],
#     "measurementTechnique": [
#       "HOBO Pendant® Temperature/Alarm and Temperature/Light Data Logger 8K and 64K",
#       "HOBO Pendant® Température/Alarme et Température/Lumière Enregistreur de données 8K et 64K"
#     ],
#     "spatialCoverage": {"geo":[
#       {
#       "@type": "GeoCoordinates",
#       "latitude": "62.1647",
#       "longitude": "75.7981",
#       "name": "Vallée de la rivière Narsajuaq"
#       }],
#      "@type": "Place" },
#     "license": "https://www.cen.ulaval.ca/nordicanad/en_modalite.aspx",
#     "publisher": { "@type": "Organization", "name": "Nordicana D", "url": "https://www.cen.ulaval.ca/nordicanad/en_index.aspx", "logo": "https://www.cen.ulaval.ca/nordicanad/images/logofloconcouleur_75pct_02.png" },
#     "provider": { "@type": "Organization", "name": "Centre d'études Nordiques (CEN)", "url": "https://www.cen.ulaval.ca/" }
# }
# </script>
